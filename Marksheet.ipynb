# %% [markdown]
# Q.) WAP for Marksheet where take 5 subject marks from user, and give grades, also give grace marks only if fails in 1 subject and grace marks is 5, if <= 3 then print ruk jana nahi more than that Fail.

# %%
h = int(input("Enter Hindi marks here:- "))
e = int(input("Enter English marks here:- "))
m = int(input("Enter Maths marks here:- "))
so = int(input("Enter So Science marks here:- "))
s = int(input("Enter Science marks here:- "))
fail_count = 0
graced = False

if((h>=0 and h <= 100) and (e>=0 and e <= 100) and (m>=0 and m <= 100) and (so>=0 and so <= 100) and (s>=0 and s <= 100)):
    print("All received marks are Valid")
    if(h>=31 and h <= 35):
        fail_count+=1
    if(e>=31 and e <= 35):
        fail_count+=1
    if(m>=31 and m <= 35):
        fail_count+=1
    if(so>=31 and so <= 35):
        fail_count+=1
    if(s>=31 and s <= 35):
        fail_count+=1
    if(fail_count==1):
        print("graced")
        graced = True
        if(h>=31 and h <= 35):
            print(" in hindi")
            h = 36
        if(e>=31 and e <= 35):
            print(" in english")
            e = 36
        if(m>=31 and m <= 35):
            print(" in math")
            m = 36
        if(so>=31 and so <= 35):
            print(" in social science")
            so = 36
        if(s>=31 and s <= 35):
            print(" in science")
            s = 36
    elif(fail_count>1 and fail_count<=3):
        print("Ruk Jana Nahi")
    elif(fail_count>3):
        print("FAIL")
    if(fail_count==0 or graced):
        tm = h+e+m+so+s
        per = tm/5
        print("Total Marks :- ",tm)
        print("Percentage is:- ",per,"%")
        if(per >= 91 and per <= 100):
            print("Grade A+")
        elif(per >= 81 and per <= 90):
            print("Grade A")
        elif(per >= 71 and per <= 80):
            print("Grade B+")
        elif(per >= 61 and per <= 70):
            print("Grade B")
        elif(per >= 51 and per <= 60):
            print("Grade C+")
        elif(per >= 41 and <= 50):
            print("Grade C")
        elif(per >= 36 and <= 40):
            print("Grade C")
        else:
            print("Fail")
#       if(31 >= s <= 35):
#             x = 36 - s
#             s = s + x
#             print("Pass by Grace with ",x," marks")
#             print("After Grace added Marks:- ",s)

        
     
else:
    print("Invalid Marks")
    if(h < 0 and h > 100):
        print("Invalid Marks in Hindi:- ",h )
    if(e < 0 and e > 100):
        print("Invalid Marks in Hindi:- ",e)
    if(m < 0 and m > 100):
        print("Invalid Marks in Hindi:- ",m )
    if(so < 0 and so > 100):
        print("Invalid Marks in Hindi:- ",so)
    if(s < 0 and s > 100):
        print("Invalid Marks in Hindi:- ",s )
# Out:
# Enter Hindi marks here:- 32
# Enter English marks here:- 40
# Enter Maths marks here:- 50
# Enter So Science marks here:- 60
# Enter Science marks here:- 70
# All received marks are Valid
# graced
#  in hindi
# Total Marks :-  256
# Percentage is:-  51.2 %
# Grade A+

# %%
# Yours
h = int(input("Enter The Value Of Hindi:- "))
e = int(input("Enter The Value Of English:- "))
m = int(input("Enter The Value Of Maths:- "))
so = int(input("Enter The Value Of So Science:- "))
s = int(input("Enter The Value Of Science:- "))
check_counter_fail=0
gress=0
if((h>=0 and h<=100) and (e>=0 and e<=100) and (m>=0 and m<=100) and (so>=0 and so<=100) and (s>=0 and s<=100)):
    if((h>=36 and h<=100) and (e>=36 and e<=100) and (m>=36 and m<=100) and (so>=36 and so<=100) and (s>=36 and s<=100)):
        print("Pass In All Sub")
        tm = h+e+m+so+s
        print("Total Marks:- ",tm)
        per = tm/5
        print("PER:- ",per,"%")
        if(per>=91 and per<=100):
            print("A+")
        elif(per>=81 and per<91):
            print("A")
        elif(per>=71 and per<81):
            print("B+")
        elif(per>=61 and per<71):
            print("B")
        elif(per>=51 and per<61):
            print("C+")
        elif(per>=41 and per<51):
            print("c")
        else:
            print("D")
    else:
        if(h<36):
            print("Fail In Hindi:- ",h)
            check_counter_fail+=1  
        if(e<36):
            print("Fail In English:- ",e)
            check_counter_fail+=1
        if(m<36):
            print("Fail In Maths:- ",m)
            check_counter_fail+=1
        if(so<36):
            print("Fail In So Science:- ",so)
            check_counter_fail+=1
        if(s<36):
            print("Fail In Science:- ",s)
            check_counter_fail+=1
        print("Total Fail Subjects IN:- ",check_counter_fail)
        if(check_counter_fail==1):            
            if(h>=30 and h<=35):
                diff_marks = 36-h
                h = h+diff_marks
                print("Pass With Grace In Hindi:- ",diff_marks)
                print("After Grace New Marks In Hindi:- ",h)
                gress=1
            if(e>=30 and e<=35):
                diff_marks = 36-e
                e = e+diff_marks
                print("Pass With Grace in English:- ",diff_marks)
                print("After Grace New Marks In English:- ",e)
                gress=1
            if(m>=30 and m<=35):
                diff_marks = 36-m
                m = m+diff_marks
                print("Pass With Grace in Maths:- ",diff_marks)
                print("After Grace New Marks In Maths:- ",m)
                gress=1
            if(so>=30 and so<=35):
                diff_marks = 36-so
                so = so+diff_marks
                print("Pass With Grace in So Science:- ",diff_marks)
                print("After Grace New Marks In So Science:- ",so)
                gress=1
            if(s>=30 and s<=35):
                diff_marks = 36-s
                s = s+diff_marks
                print("Pass With Grace in Science:- ",diff_marks)
                print("After Grace New Marks In Science:- ",s)
                gress=1
            if(gress==1):
                tm = h+e+m+so+s
                print("Total Marks:- ",tm)
                per = tm/5
                print("PER:- ",per,"%")
                if(per>=91 and per<=100):
                    print("A+")
                elif(per>=81 and per<91):
                    print("A")
                elif(per>=71 and per<81):
                    print("B+")
                elif(per>=61 and per<71):
                    print("B")
                elif(per>=51 and per<61):
                    print("C+")
                elif(per>=41 and per<51):
                    print("c")
                else:
                    print("D")
        if(check_counter_fail<=3 and gress==0):
            print("RUK JANA NAHI...")
            if(h<36):
                h = int(input("Enter The New Hindi Marks:- "))
            if(e<36):
                e = int(input("Enter The New English Marks:- "))
            if(m<36):
                m = int(input("Enter The New Maths Marks:- "))
            if(so<36):
                so = int(input("Enter The New So Science Marks:- "))
            if(s<36):
                s = int(input("Enter The New Science Marks:- "))
            if((h>=0 and h<=100) and (e>=0 and e<=100) and (m>=0 and m<=100) and (so>=0 and so<=100) and (s>=0 and s<=100)):
                print("Valid All New Marks")
                tm = h+e+m+so+s
                print("Total Marks:- ",tm)
                per = tm/5
                print("PER:- ",per,"%")
                if(per>=91 and per<=100):
                    print("A+")
                elif(per>=81 and per<91):
                    print("A")
                elif(per>=71 and per<81):
                    print("B+")
                elif(per>=61 and per<71):
                    print("B")
                elif(per>=51 and per<61):
                    print("C+")
                elif(per>=41 and per<51):
                    print("c")
                else:
                    print("D")
            else:
                print("Not Valid New Marks")
                if(h<0 or h>100):
                    print("Invalid New Marks In Hindi:- ",h)
                if(e<0 or e>100):
                    print("Invalid New Marks In English:- ",e)
                if(m<0 or m>100):
                    print("Invalid New Marks In Maths:- ",m)
                if(so<0 or so>100):
                    print("Invalid New Marks In So Science:- ",so)
                if(s<0 or s>100):
                    print("Invalid New Marks In Science:- ",s)
                
        if(check_counter_fail>=4):
            print("Fail Hai BAHI TU KUCH NAHI HOGA TERA PED PED")
else:
    print("Not Valid Marks")
    if(h<0 or h>100):
        print("Invalid Marks In Hindi:- ",h)
    if(e<0 or e>100):
        print("Invalid Marks In English:- ",e)
    if(m<0 or m>100):
        print("Invalid Marks In Maths:- ",m)
    if(so<0 or so>100):
        print("Invalid Marks In So Science:- ",so)
    if(s<0 or s>100):
        print("Invalid Marks In Science:- ",s)

# %%
# Mine

h = int(input("Enter Hindi marks here:- "))
e = int(input("Enter English marks here:- "))
m = int(input("Enter Maths marks here:- "))
so = int(input("Enter So Science marks here:- "))
s = int(input("Enter Science marks here:- "))
fail_count = 0

if((h>=0 and h<=100) and (e>=0 and e<=100) and (m>=0 and m<=100) and (so>=0 and so<=100) and (s>=0 and s<=100)):
    if((h>=36 and h<=100) and (e>=36 and e<=100) and (m>=36 and m<=100) and (so>=36 and so<=100) and (s>=36 and s<=100)):
        print("Pass In All Sub")
        tm = h+e+m+so+s
        print("Total Marks:- ",tm)
        per = tm/5
        print("PER:- ",per,"%")
        if(per>=91 and per<=100):
            print("A+")
        elif(per>=81 and per<91):
            print("A")
        elif(per>=71 and per<81):
            print("B+")
        elif(per>=61 and per<71):
            print("B")
        elif(per>=51 and per<61):
            print("C+")
        elif(per>=41 and per<51):
            print("c")
        else:
            print("D")
    else:
        if(h<36):
            print("Fail In Hindi:- ",h)
            fail_count+=1  
        if(e<36):
            print("Fail In English:- ",e)
            fail_count+=1
        if(m<36):
            print("Fail In Maths:- ",m)
            fail_count+=1
        if(so<36):
            print("Fail In So Science:- ",so)
            fail_count+=1
        if(s<36):
            print("Fail In Science:- ",s)
            fail_count+=1
        print("Total Fail Subjects IN:- ",fail_count)
        if(fail_count==1):            
            if(h>=30 and h<=35):
                diff_marks = 36-h
                h = h+diff_marks
                print("Pass With Grace In Hindi:- ",diff_marks)
                print("After Grace New Marks In Hindi:- ",h)
                gress=1
            if(e>=30 and e<=35):
                diff_marks = 36-e
                e = e+diff_marks
                print("Pass With Grace in English:- ",diff_marks)
                print("After Grace New Marks In English:- ",e)
                gress=1
            if(m>=30 and m<=35):
                diff_marks = 36-m
                m = m+diff_marks
                print("Pass With Grace in Maths:- ",diff_marks)
                print("After Grace New Marks In Maths:- ",m)
                gress=1
            if(so>=30 and so<=35):
                diff_marks = 36-so
                so = so+diff_marks
                print("Pass With Grace in So Science:- ",diff_marks)
                print("After Grace New Marks In So Science:- ",so)
                gress=1
            if(s>=30 and s<=35):
                diff_marks = 36-s
                s = s+diff_marks
                print("Pass With Grace in Science:- ",diff_marks)
                print("After Grace New Marks In Science:- ",s)
                gress=1
            if(gress==1):
                tm = h+e+m+so+s
                print("Total Marks:- ",tm)
                per = tm/5
                print("PER:- ",per,"%")
                if(per>=91 and per<=100):
                    print("A+")
                elif(per>=81 and per<91):
                    print("A")
                elif(per>=71 and per<81):
                    print("B+")
                elif(per>=61 and per<71):
                    print("B")
                elif(per>=51 and per<61):
                    print("C+")
                elif(per>=41 and per<51):
                    print("c")
                else:
                    print("D")
        if(fail_count<=3 and gress==0):
            print("RUK JANA NAHI...")
            if(h<36):
                h = int(input("Enter The New Hindi Marks:- "))
            if(e<36):
                e = int(input("Enter The New English Marks:- "))
            if(m<36):
                m = int(input("Enter The New Maths Marks:- "))
            if(so<36):
                so = int(input("Enter The New So Science Marks:- "))
            if(s<36):
                s = int(input("Enter The New Science Marks:- ")) 
            if((h>=0 and h<=100) and (e>=0 and e<=100) and (m>=0 and m<=100) and (so>=0 and so<=100) and (s>=0 and s<=100)):
                print("Valid All New Marks")
                tm = h+e+m+so+s
                print("Total Marks:- ",tm)
                per = tm/5
                print("PER:- ",per,"%")
                if(per>=91 and per<=100):
                    print("A+")
                elif(per>=81 and per<91):
                    print("A")
                elif(per>=71 and per<81):
                    print("B+")
                elif(per>=61 and per<71):
                    print("B")
                elif(per>=51 and per<61):
                    print("C+")
                elif(per>=41 and per<51):
                    print("c")
                else:
                    print("D")
            else:
                print("Not Valid New Marks")
                if(h<0 or h>100):
                    print("Invalid New Marks In Hindi:- ",h)
                if(e<0 or e>100):
                    print("Invalid New Marks In English:- ",e)
                if(m<0 or m>100):
                    print("Invalid New Marks In Maths:- ",m)
                if(so<0 or so>100):
                    print("Invalid New Marks In So Science:- ",so)
                if(s<0 or s>100):
                    print("Invalid New Marks In Science:- ",s)
                
        if(fail_count>=4):
            print("Fail Hai BHAI TU KUCH NAHI HOGA TERA PED PED")    
        
        
                
else:
    print("Not Valid Marks")
    if(h<0 or h>100):
        print("Invalid Marks In Hindi:- ",h)
    if(e<0 or e>100):
        print("Invalid Marks In English:- ",e)
    if(m<0 or m>100):
        print("Invalid Marks In Maths:- ",m)
    if(so<0 or so>100):
        print("Invalid Marks In So Science:- ",so)
    if(s<0 or s>100):
        print("Invalid Marks In Science:- ",s)
# Out:
# Enter Hindi marks here:- 31
# Enter English marks here:- 32
# Enter Maths marks here:- 32
# Enter So Science marks here:- 40
# Enter Science marks here:- 50
# Fail In Hindi:-  31
# Fail In English:-  32
# Fail In Maths:-  32
# Total Fail Subjects IN:-  3
# RUK JANA NAHI...
# Enter The New Hindi Marks:- 40
# Enter The New English Marks:- 40
# Enter The New Maths Marks:- 40
# Valid All New Marks
# Total Marks:-  210
# PER:-  42.0 %
# c
