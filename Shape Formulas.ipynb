# %%
# Area of Circle(pie*square(r))
r = float(input("Enter The Radius- "))
pie = float(input("Enter decimal value of pie- "))
area = float(pie*r**2)
print("The Area of Circle is = ",area)
# Out:
# Enter The Radius- 5
# Enter decimal value of pie- 3.14
# The Area of Circle is =  78.5

# %%
# Area of Square
side = int(input("Enter The Side value: "))
area = side*side
print("Area of Square is :",area)
# Out:
# Enter The Side value: 40
# Area of Square is : 1600

# %%
# Area of Rectangle
length = int(input("Enter Length - "))
width = int(input("Enter Width - "))
area = length*width
print("The Area of Rectangle is =",area)
# Out:
# Enter Length - 34
# Enter Width - 36
# The Area of Rectangle is = 1224

# %%
# Area of triangle
Height=int(input("Enter the Height:- "))
Base=int(input("Enter the Base:- "))
Area=(Height*Base)/2
print("The Area of Triangle is:",Area)
# Out:
# Enter the Height:- 30
# Enter the Base:- 20
# The Area of Triangle is: 300.0

# %%
# Compound Interest
p = float(input("Enter Principle amount : "))
r = float(input("Enter Rate of interest % : "))
t = float(input("Enter Time in years : "))

A = (p * (1 + r/100)**t)
print(A)
CI = A-p

print("Compound Interest",CI)
